# 47  6.4  3.1  5.5  1.8   Iris-virginica
# 48  6.0  3.0  4.8  1.8   Iris-virginica
# 49  6.9  3.1  5.4  2.1   Iris-virginica
# 50  6.7  3.1  5.6  2.4   Iris-virginica
# 51  6.9  3.1  5.1  2.3   Iris-virginica
# 52  5.8  2.7  5.1  1.9   Iris-virginica
# 53  6.8  3.2  5.9  2.3   Iris-virginica
# 54  6.7  3.3  5.7  2.5   Iris-virginica
# 55  6.7  3.0  5.2  2.3   Iris-virginica
# 56  6.3  2.5  5.0  1.9   Iris-virginica
# 57  6.5  3.0  5.2  2.0   Iris-virginica
# 58  6.2  3.4  5.4  2.3   Iris-virginica
# 59  5.9  3.0  5.1  1.8   Iris-virginica

# %%
data["f5"].value_counts()
# Out:
# Iris-virginica     30
# Iris-versicolor    15
# Iris-setosa        15
# Name: f5, dtype: int64

# %%
sns.FacetGrid(data, hue="f5", size=5) \
   .map(plt.scatter, "f1", "f2") \
   .add_legend()

# %%
#map data into arrays
s=np.asarray([1,0,0])
ve=np.asarray([0,1,0])
vi=np.asarray([0,0,1])
data['f5'] = data['f5'].map({'Iris-setosa': s, 'Iris-versicolor': ve,'Iris-virginica':vi})

# %%
data
# Out:
#      f1   f2   f3   f4         f5
# 0   5.1  3.5  1.4  0.2  [1, 0, 0]
# 1   4.9  3.0  1.4  0.2  [1, 0, 0]
# 2   4.7  3.2  1.3  0.2  [1, 0, 0]
# 3   4.6  3.1  1.5  0.2  [1, 0, 0]
# 4   5.3  3.6  1.4  0.2  [1, 0, 0]
# 5   5.4  3.9  1.7  0.4  [1, 0, 0]
# 6   4.6  3.4  1.4  0.3  [1, 0, 0]
# 7   5.0  3.4  1.5  0.2  [1, 0, 0]
# 8   4.4  2.9  1.4  0.2  [1, 0, 0]
# 9   4.9  3.1  1.5  0.1  [1, 0, 0]
# 10  5.4  3.7  1.5  0.2  [1, 0, 0]
# 11  4.8  3.4  1.6  0.2  [1, 0, 0]
# 12  4.8  3.0  1.4  0.1  [1, 0, 0]
# 13  4.3  3.0  1.1  0.1  [1, 0, 0]
# 14  5.8  4.0  1.2  0.2  [1, 0, 0]
# 15  5.7  4.4  1.5  0.4  [0, 1, 0]
# 16  5.4  3.9  1.3  0.4  [0, 1, 0]
# 17  5.1  3.5  1.4  0.3  [0, 1, 0]
# 18  5.7  3.8  1.7  0.3  [0, 1, 0]
# 19  5.1  3.8  1.5  0.3  [0, 1, 0]
# 20  5.4  3.4  1.7  0.2  [0, 1, 0]
# 21  5.1  3.7  1.5  0.4  [0, 1, 0]
# 22  4.6  3.6  1.0  0.2  [0, 1, 0]
# 23  5.1  3.3  1.7  0.5  [0, 1, 0]
# 24  4.8  3.4  1.9  0.2  [0, 1, 0]
# 25  5.0  3.0  1.6  0.2  [0, 1, 0]
# 7   5.0  3.4  1.5  0.2  [1, 0, 0]

# %%
data=data.reset_index(drop=True)

# %%
data
# Out:
#      f1   f2   f3   f4         f5
# 0   7.2  3.2  6.0  1.8  [0, 0, 1]
# 1   4.9  3.1  1.5  0.1  [1, 0, 0]
# 2   4.6  3.4  1.4  0.3  [1, 0, 0]
# 3   6.0  3.0  4.8  1.8  [0, 0, 1]
# 4   6.7  3.1  5.6  2.4  [0, 0, 1]
# 5   5.2  3.5  1.5  0.2  [0, 1, 0]
# 6   5.0  3.4  1.6  0.4  [0, 1, 0]
# 7   6.4  3.1  5.5  1.8  [0, 0, 1]
# 8   6.7  3.3  5.7  2.5  [0, 0, 1]
# 9   7.4  2.8  6.1  1.9  [0, 0, 1]
# 10  6.2  3.4  5.4  2.3  [0, 0, 1]
# 11  6.7  3.3  5.7  2.1  [0, 0, 1]
# 12  4.3  3.0  1.1  0.1  [1, 0, 0]
# 13  7.2  3.0  5.8  1.6  [0, 0, 1]
# 14  5.1  3.3  1.7  0.5  [0, 1, 0]
# 15  4.9  3.0  1.4  0.2  [1, 0, 0]
# 16  5.4  3.9  1.7  0.4  [1, 0, 0]
# 17  6.9  3.2  5.7  2.3  [0, 0, 1]
# 18  5.6  2.8  4.9  2.0  [0, 0, 1]
# 19  5.4  3.4  1.7  0.2  [0, 1, 0]
# 20  5.7  4.4  1.5  0.4  [0, 1, 0]
# 21  6.3  3.4  5.6  2.4  [0, 0, 1]
# 22  5.1  3.7  1.5  0.4  [0, 1, 0]
# 23  6.1  3.0  4.9  1.8  [0, 0, 1]
# 24  6.3  2.7  4.9  1.8  [0, 0, 1]
# 25  5.4  3.9  1.3  0.4  [0, 1, 0]
# 26  6.3  2.8  5.1  1.5  [0, 0, 1]
# 27  6.5  3.0  5.2  2.0  [0, 0, 1]
# 28  5.1  3.8  1.5  0.3  [0, 1, 0]
# 29  7.7  2.8  6.7  2.0  [0, 0, 1]
# 30  5.0  3.0  1.6  0.2  [0, 1, 0]
# 31  4.6  3.1  1.5  0.2  [1, 0, 0]
# 32  6.9  3.1  5.4  2.1  [0, 0, 1]
# 33  5.3  3.6  1.4  0.2  [1, 0, 0]
# 34  6.4  2.8  5.6  2.1  [0, 0, 1]
# 35  5.7  3.8  1.7  0.3  [0, 1, 0]
# 36  7.7  3.0  6.1  2.3  [0, 0, 1]
# 37  4.4  2.9  1.4  0.2  [1, 0, 0]
# 38  5.1  3.5  1.4  0.3  [0, 1, 0]
# 39  7.9  3.8  6.4  2.0  [0, 0, 1]
# 40  5.2  3.4  1.4  0.2  [0, 1, 0]
# 41  5.1  3.5  1.4  0.2  [1, 0, 0]
# 42  6.8  3.2  5.9  2.3  [0, 0, 1]
# 43  6.9  3.1  5.1  2.3  [0, 0, 1]
# 44  4.7  3.2  1.3  0.2  [1, 0, 0]
# 45  5.8  2.7  5.1  1.9  [0, 0, 1]
# 46  5.9  3.0  5.1  1.8  [0, 0, 1]
# 47  4.6  3.6  1.0  0.2  [0, 1, 0]
# 48  4.8  3.4  1.9  0.2  [0, 1, 0]
# 49  6.1  2.6  5.6  1.4  [0, 0, 1]
# 50  4.8  3.4  1.6  0.2  [1, 0, 0]
# 51  6.4  2.8  5.6  2.2  [0, 0, 1]
# 52  6.3  2.5  5.0  1.9  [0, 0, 1]
# 53  4.8  3.0  1.4  0.1  [1, 0, 0]
# 54  5.4  3.7  1.5  0.2  [1, 0, 0]
# 55  6.7  3.0  5.2  2.3  [0, 0, 1]
# 56  6.2  2.8  4.8  1.8  [0, 0, 1]
# 57  4.7  3.2  1.6  0.2  [0, 1, 0]
# 58  5.8  4.0  1.2  0.2  [1, 0, 0]
# 59  5.0  3.4  1.5  0.2  [1, 0, 0]

# %%
#training data
x_input=data.ix[0:30,['f1','f2','f3','f4']]
temp=data['f5']
y_input=temp[0:31]
#test data
x_test=data.ix[31:58,['f1','f2','f3','f4']]
y_test=temp[31:59]
# Out:
# C:\Users\Naqsh\Anaconda3\envs\Project\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix

# %%
#placeholders and variables. input has 4 features and output has 3 classes
x=tf.placeholder(tf.float32,shape=[None,4])
y_=tf.placeholder(tf.float32,shape=[None, 3])
#weight and bias
W=tf.Variable(tf.zeros([4,3]))
b=tf.Variable(tf.zeros([3]))

# %%
# model 
#softmax function for multiclass classification
y = tf.nn.softmax(tf.matmul(x, W) + b)

# %%
#loss function
cross_entropy = tf.reduce_mean(-tf.reduce_sum(y_ * tf.log(y), reduction_indices=[1]))

# %%
#optimiser -
train_step = tf.train.AdamOptimizer(0.01).minimize(cross_entropy)
#calculating accuracy of our model 
correct_prediction = tf.equal(tf.argmax(y,1), tf.argmax(y_,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
#session parameters
sess = tf.InteractiveSession()
#initialising variables
init = tf.global_variables_initializer()
sess.run(init)
#number of interations
epoch=2000

# %%
for step in range(epoch):
   _, c=sess.run([train_step,cross_entropy], feed_dict={x: x_input, y_:[t for t in y_input.as_matrix()]})
   if step%500==0 :
    print (c)
# Out:
# 1.09861
# 0.268226
# 0.237345
# 0.218126

# %%
#random testing at Sn.130
a=data.ix[59,['f1','f2','f3','f4']]
b=a.reshape(1,4)
largest = sess.run(tf.arg_max(y,1), feed_dict={x: b})[0]
if largest==0:
    print ("flower is :Iris-setosa")
elif largest==1:
    print ("flower is :Iris-versicolor")
else :
    print ("flower is :Iris-virginica")
# Out:
# flower is :Iris-versicolor
# C:\Users\Naqsh\Anaconda3\envs\Project\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
print sess.run(accuracy,feed_dict={x: x_test, y_:[t for t in y_test.as_matrix()]})
# Out:
#   File "<ipython-input-22-46ec379eea4e>", line 1
#     print sess.run(accuracy,feed_dict={x: x_test, y_:[t for t in y_test.as_matrix()]})
#              ^
# SyntaxError: invalid syntax
